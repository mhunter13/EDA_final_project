# %%
import pandas as pd

# %%
stations = pd.read_csv("NYC_Transit_Subway_Entrance_And_Exit_Data.csv")
stations.head()
# Out:
#   Division      Line Station Name  Station Latitude  Station Longitude Route1  \
# 0      BMT  4 Avenue      25th St         40.660397         -73.998091      R
# 1      BMT  4 Avenue      25th St         40.660397         -73.998091      R
# 2      BMT  4 Avenue      36th St         40.655144         -74.003549      N
# 3      BMT  4 Avenue      36th St         40.655144         -74.003549      N
# 4      BMT  4 Avenue      36th St         40.655144         -74.003549      N
#
#   Route2 Route3 Route4 Route5  ...    ADA ADA Notes  Free Crossover  \
# 0    NaN    NaN    NaN    NaN  ...  False       NaN           False
# 1    NaN    NaN    NaN    NaN  ...  False       NaN           False
# 2      R    NaN    NaN    NaN  ...  False       NaN            True
# 3      R    NaN    NaN    NaN  ...  False       NaN            True
# 4      R    NaN    NaN    NaN  ...  False       NaN            True
#
#    North South Street  East West Street  Corner Entrance Latitude  \
# ...

# %%
stations.columns
# Out:
# Index(['Division', 'Line', 'Station Name', 'Station Latitude',
#        'Station Longitude', 'Route1', 'Route2', 'Route3', 'Route4', 'Route5',
#        'Route6', 'Route7', 'Route8', 'Route9', 'Route10', 'Route11',
#        'Entrance Type', 'Entry', 'Exit Only', 'Vending', 'Staffing',
#        'Staff Hours', 'ADA', 'ADA Notes', 'Free Crossover',
#        'North South Street', 'East West Street', 'Corner', 'Entrance Latitude',
#        'Entrance Longitude', 'Station Location', 'Entrance Location'],
#       dtype='object')

# %%
stations.drop(stations.columns[5:], axis = 1, inplace=True)
stations.head()
# Out:
#    Division      Line Station Name  Station Latitude  Station Longitude
# 0       BMT  4 Avenue      25th St         40.660397         -73.998091
# 2       BMT  4 Avenue      36th St         40.655144         -74.003549
# 5       BMT  4 Avenue      45th St         40.648939         -74.010006
# 9       BMT  4 Avenue      53rd St         40.645069         -74.014034
# 14      BMT  4 Avenue      59th St         40.641362         -74.017881

# %%
stations.groupby('Station Name').count()
# Out:
#                              Division  Line  Station Latitude  \
# Station Name
# 103rd St                            4     4                 4
# 104th St-102nd St                   1     1                 1
# 104th St-Oxford Av                  1     1                 1
# 110th St                            1     1                 1
# 110th St-Central Park North         1     1                 1
# ...                               ...   ...               ...
# Woodside Av-61st St                 1     1                 1
# World Trade Center                  1     1                 1
# Yankee Stadium-161st St             2     2                 2
# York St                             1     1                 1
# Zerega Av                           1     1                 1
#
#                              Station Longitude
# Station Name
# 103rd St                                     4
# 104th St-102nd St                            1
# 104th St-Oxford Av                           1
# ...

# %%
#why does Yankee Stadium 161st St have 16 different entries?
mask = stations['Station Name'] == 'Yankee Stadium-161st St'
stations[mask]
# Out:
#      Division       Line             Station Name  Station Latitude  \
# 819       IND  Concourse  Yankee Stadium-161st St         40.827905
# 820       IND  Concourse  Yankee Stadium-161st St         40.827905
# 821       IND  Concourse  Yankee Stadium-161st St         40.827905
# 822       IND  Concourse  Yankee Stadium-161st St         40.827905
# 823       IND  Concourse  Yankee Stadium-161st St         40.827905
# 824       IND  Concourse  Yankee Stadium-161st St         40.827905
# 825       IND  Concourse  Yankee Stadium-161st St         40.827905
# 826       IND  Concourse  Yankee Stadium-161st St         40.827905
# 1531      IRT     Jerome  Yankee Stadium-161st St         40.827994
# 1532      IRT     Jerome  Yankee Stadium-161st St         40.827994
# 1533      IRT     Jerome  Yankee Stadium-161st St         40.827994
# 1534      IRT     Jerome  Yankee Stadium-161st St         40.827994
# 1535      IRT     Jerome  Yankee Stadium-161st St         40.827994
# ...

# %%
stations.drop_duplicates(inplace=True)
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 475 entries, 0 to 1865
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Division           475 non-null    object
#  1   Line               475 non-null    object
#  2   Station Name       475 non-null    object
#  3   Station Latitude   475 non-null    float64
#  4   Station Longitude  475 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 22.3+ KB

# %%
df_stations = stations.groupby('Station Name').mean().reset_index()
df_stations = df_stations.round(6)  
df_stations.head()
# Out:
#                   Station Name  Station Latitude  Station Longitude
# 0                     103rd St         40.784001         -73.935003
# 1            104th St-102nd St         40.695178         -73.844330
# 2           104th St-Oxford Av         40.681711         -73.837683
# 3                     110th St         40.795020         -73.944250
# 4  110th St-Central Park North         40.799075         -73.951822

# %%
df_stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356 entries, 0 to 355
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Station Name       356 non-null    object
#  1   Station Latitude   356 non-null    float64
#  2   Station Longitude  356 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 8.5+ KB

# %%
df_stations.columns
# Out:
# Index(['Station Name', 'Station Latitude', 'Station Longitude'], dtype='object')

# %%
# to_replace = ['rd', 'th', 'nd','st','']
# df_stations['Station Name'] = df_stations['Station Name'].replace(to_replace,'')
df_stations['Station Name'] = df_stations['Station Name'].str.replace('th','')
df_stations['Station Name'] = df_stations['Station Name'].str.replace('nd','')
df_stations['Station Name'] = df_stations['Station Name'].str.replace('rd','')
df_stations['Station Name'] = df_stations['Station Name'].str.replace('st','')
df_stations = df_stations.sort_values('Station Name').reset_index()
df_stations.head(50)
# Out:
#     index                 Station Name  Station Latitude  Station Longitude
# 0      39                         1 Av         40.730953         -73.981628
# 1       0                       103 St         40.784001         -73.935003
# 2       1                104 St-102 St         40.695178         -73.844330
# 3       2               104 St-Oxfo Av         40.681711         -73.837683
# 4       3                       110 St         40.795020         -73.944250
# 5       4      110 St-Central Park Nor         40.799075         -73.951822
# 6       5                       111 St         40.724574         -73.845840
# 7       6          111 St-Greenwood Av         40.684331         -73.832163
# 8       7                       116 St         40.801937         -73.948708
# 9       8   116 St-Columbia University         40.807722         -73.964110
# 10      9                       121 St         40.700492         -73.828294
# ...

# %%
df_stations.iloc[50:100]
# Out:
#     index                     Station Name  Station Latitude  \
# 50     47                           233 St         40.893193
# 51     48                           238 St         40.884667
# 52     49                 238 St-Nereid Av         40.898379
# 53     52                            25 Av         40.597704
# 54     53                            25 St         40.660397
# 55     54                            28 St         40.745260
# 56     63                             3 Av         40.732849
# 57     56                     30 Av-Gra Av         40.766779
# 58     57                            33 St         40.746081
# 59     59                            34 St         40.750486
# 60     58                 34 St Hudson Yas         40.755882
# 61     60              36 Av-Washington Av         40.756804
# 62     61                            36 St         40.703592
# 63     62                   39 Av-Beebe Av         40.752882
# ...

# %%
((df_stations.groupby('Station Name').count() > 1) == True).count()
# Out:
# Station Latitude     356
# Station Longitude    356
# dtype: int64

# %%
df_stations.to_csv('station_list.csv')
